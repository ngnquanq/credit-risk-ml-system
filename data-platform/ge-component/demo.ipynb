# %%
import great_expectations as gx

context = gx.get_context()

PG_CONN = "postgresql+psycopg2://quang_user:quang2011@localhost:5432/homecredit"

# %%
# 1. Add PostgreSQL datasource
pg = context.data_sources.add_or_update_postgres(name="local_pg", connection_string=PG_CONN)

# 2. Define table asset (existing table)
table = pg.add_table_asset(name="user_table_asset",schema_name="data", table_name="application_train")

# 3. Build a batch request
batch_request = table.build_batch_request()

# %%
validator = context.get_validator(
    batch_request=batch_request,
    create_expectation_suite_with_name="users_suite"
)

# %%
# 5. Add expectations
validator.expect_column_to_exist("TARGET")
validator.expect_column_to_exist("email")
# validator.expect_column_values_to_be_in_set("status", {"active","inactive"})
# validator.expect_column_values_to_be_between("age", min_value=0, max_value=120)

# 6. Validate
results = validator.validate()
print("Success:", results.success)
for r in results.results:
    # print(r.expectation_config.type, r.success)
    pass
# 7. Optionally, save suite and docs or integrate a checkpoint
# validator.save_expectation_suite(discard_failed_expectations=False)
context.build_data_docs()
context.open_data_docs()
# Out:
# /home/nhatquang/anaconda3/envs/dataEngineer-env/lib/python3.10/site-packages/great_expectations/expectations/expectation.py:1473: UserWarning: `result_format` configured at the Validator-level will not be persisted. Please add the configuration to your Checkpoint config or checkpoint_run() method instead.
#   warnings.warn(
# ...
# Calculating Metrics: 100%|██████████| 2/2 [00:00<00:00, 1413.18it/s]
# Success: False

# %%
context.build_data_docs()
# Out:
# {'local_site': 'file:///tmp/tmp_75wxwkz/index.html'}
